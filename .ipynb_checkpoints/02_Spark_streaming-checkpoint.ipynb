# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import os

spark = SparkSession.builder \
    .appName("CryptoPipeline") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.3") \
    .getOrCreate()

print(f"Spark 버전: {spark.version}")
# Out:
# 26/03/19 16:19:12 WARN Utils: Your hostname, DESKTOP-2NP0SM4 resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/03/19 16:19:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/woo2910/.local/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/woo2910/.ivy2/cache
# The jars for the packages stored in: /home/woo2910/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-ea4690b8-b6f6-4f83-aca2-f106ae7be182;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.3 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.3 in central
# 	found org.apache.kafka#kafka-clients;3.4.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.5 in central
# 	found org.slf4j#slf4j-api;2.0.7 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# :: resolution report :: resolve 458ms :: artifacts dl 26ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.3 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.3 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.7 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.5 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-ea4690b8-b6f6-4f83-aca2-f106ae7be182
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/11ms)
# 26/03/19 16:19:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/19 16:19:15 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Spark 버전: 3.5.3

# %%
schema = StructType([
    StructField("symbol", StringType()),
    StructField("price", DoubleType()),
    StructField("timestamp", LongType())
])

df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "raw-prices") \
    .load()

parsed_df = df.select(
    from_json(col("value").cast("string"), schema).alias("data")
).select("data.*") \
 .withColumn("timestamp", to_timestamp(col("timestamp") / 1000))

ma_df = parsed_df \
    .filter(col("price") > 0) \
    .filter(col("price") < 1000000) \
    .dropDuplicates(["symbol", "timestamp"]) \
    .groupBy(
        window(col("timestamp"), "1 minute"),
        col("symbol")
    ) \
    .agg(
        avg("price").alias("moving_avg"),
        min("price").alias("min_price"),
        max("price").alias("max_price")
    )

print("Spark Streaming 설정 완료!")
# Out:
# Spark Streaming 설정 완료!

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="crypto",
    user="postgres",
    password="password"
)

cursor = conn.cursor()
print("TimescaleDB 연결 성공!")
# Out:
# TimescaleDB 연결 성공!
# -------------------------------------------
# Batch: 44
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69699.013125      |69670.01 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.5356250000001 |642.12   |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4520343750000002|1.4515   |1.4525   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.99193548387095 |88.92    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2153.1321875      |2148.42  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 45
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69697.07176470588 |69666.01 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.5150000000001 |642.12   |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4520484848484851|1.4515   |1.4525   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.98848484848483 |88.92    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2152.920588235294 |2148.42  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
#
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69695.65527777777 |69666.01 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.4969444444446 |642.12   |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4520800000000003|1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.98599999999998 |88.92    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2152.7624999999994|2148.42  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69694.56631578947 |69666.01 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.4802631578948 |642.12   |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4521263157894737|1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.98378378378376 |88.92    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2152.5992105263153|2148.42  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69693.21125000001 |69661.98 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.4642500000001 |642.12   |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4521375         |1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.97974358974356 |88.9     |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2152.4354999999996|2148.42  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69691.98857142858 |69661.98 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.4488095238096 |642.12   |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.452147619047619 |1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.97634146341461 |88.9     |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2152.2735714285714|2148.42  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69690.44818181818 |69658.1  |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.4336363636364 |642.1    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4521511627906978|1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.97302325581394 |88.9     |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2152.0940909090905|2148.24  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 51
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69688.29765957447 |69653.39 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.4169565217392 |642.0    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.452163043478261 |1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.9673913043478  |88.86    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2151.9273913043476|2148.1   |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 52
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69687.21693877551 |69653.39 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.395918367347  |642.0    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4521687500000002|1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.96458333333332 |88.86    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2151.7071428571426|2148.06  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 53
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69686.24392156863 |69653.39 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.3890196078431 |642.0    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4521860000000002|1.4515   |1.4527   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.96239999999997 |88.86    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2151.6098039215685|2148.06  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 54
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69685.12528301888 |69653.39 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.3830188679245 |642.0    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4522076923076925|1.4515   |1.4528   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.9605769230769  |88.86    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2151.548113207547 |2148.06  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 55
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69684.29563636365 |69653.39 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.3778181818183 |642.0    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.452238181818182 |1.4515   |1.4529   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.95907407407405 |88.86    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2151.5294545454544|2148.06  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 56
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69683.82894736844 |69653.39 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.3745614035089 |642.0    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.452261403508772 |1.4515   |1.4529   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.95821428571426 |88.86    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2151.5359649122806|2148.06  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 57
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BTCUSDT|69683.63716666668 |69653.39 |69718.72 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|BNBUSDT|642.3720000000001 |642.0    |642.76   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|XRPUSDT|1.4523016666666668|1.4515   |1.4531   |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.95677966101692 |88.86    |89.02    |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|ETHUSDT|2151.5358333333334|2148.06  |2155.03  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 58
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.935            |88.93    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69679.805         |69679.62 |69679.99 |
# |{2026-03-19 16:21:00, 2026-03-19 16:22:00}|SOLUSDT|88.95633333333332 |88.86    |89.02    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.325           |642.32   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4533            |1.4532   |1.4534   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2151.0550000000003|2150.82  |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+

# %%
# 테이블 생성
cursor.execute("""
    CREATE TABLE IF NOT EXISTS crypto_prices (
        time        TIMESTAMPTZ NOT NULL,
        symbol      TEXT NOT NULL,
        moving_avg  DOUBLE PRECISION,
        min_price   DOUBLE PRECISION,
        max_price   DOUBLE PRECISION
    );
""")

# TimescaleDB 하이퍼테이블로 변환 (시계열 최적화)
cursor.execute("""
    SELECT create_hypertable('crypto_prices', 'time', if_not_exists => TRUE);
""")

conn.commit()
print("테이블 생성 완료!")
# Out:
# 테이블 생성 완료!
# -------------------------------------------
# Batch: 59
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.93333333333334 |88.93    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69678.01749999999 |69676.23 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.3275000000001 |642.32   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.453425          |1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2151.0950000000003|2150.82  |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 60
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.922            |88.88    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69673.93666666666 |69656.55 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.2800000000001 |642.13   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534500000000001|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2150.855          |2150.0   |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 61
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.91142857142857 |88.88    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69671.4325        |69656.55 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.24125         |642.11   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534625         |1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2150.6575000000003|2149.88  |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 62
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.90666666666667 |88.88    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69669.302         |69656.55 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.195           |642.01   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534500000000001|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2150.4770000000003|2149.75  |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 63
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.90272727272726 |88.88    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69667.02833333334 |69653.67 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.1641666666668 |642.01   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534583333333335|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2150.3208333333337|2149.32  |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 64
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.90076923076923 |88.88    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69665.1192857143  |69653.66 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.142142857143  |642.01   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534642857142859|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2150.1978571428576|2149.32  |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 65
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.896            |88.85    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69663.35625000001 |69651.0  |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.1143750000001 |641.92   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534500000000001|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2150.0087500000004|2148.3   |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 66
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.89176470588235 |88.85    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69661.36055555557 |69645.02 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.0927777777779 |641.92   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534333333333336|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2149.8677777777784|2148.3   |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 67
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.89             |88.85    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69660.32450000002 |69645.02 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.0755000000001 |641.92   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534250000000002|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2149.8530000000005|2148.3   |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 68
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.89045454545455 |88.85    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69659.47636363638 |69645.02 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.0581818181819 |641.88   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534227272727274|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2149.856363636364 |2148.3   |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# -------------------------------------------
# Batch: 69
# -------------------------------------------
# +------------------------------------------+-------+------------------+---------+---------+
# |window                                    |symbol |moving_avg        |min_price|max_price|
# +------------------------------------------+-------+------------------+---------+---------+
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|SOLUSDT|88.89041666666668 |88.85    |88.94    |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BTCUSDT|69659.32375000001 |69645.02 |69679.99 |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|BNBUSDT|642.0508333333335 |641.88   |642.33   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|XRPUSDT|1.4534416666666667|1.4532   |1.4538   |
# |{2026-03-19 16:22:00, 2026-03-19 16:23:00}|ETHUSDT|2149.9162500000007|2148.3   |2151.29  |
# +------------------------------------------+-------+------------------+---------+---------+
# [Stage 141:====================================>               (142 + 12) / 200]

# %%
def save_to_db(batch_df, batch_id):
    rows = batch_df.collect()
    for row in rows:
        cursor.execute("""
            INSERT INTO crypto_prices (time, symbol, moving_avg, min_price, max_price)
            VALUES (%s, %s, %s, %s, %s)
        """, (
            row['window']['end'],
            row['symbol'],
            row['moving_avg'],
            row['min_price'],
            row['max_price']
        ))
    conn.commit()
    print(f"배치 {batch_id} 저장 완료! ({len(rows)}개)")

os.makedirs("/tmp/checkpoint", exist_ok=True)

query = ma_df \
    .writeStream \
    .outputMode("update") \
    .foreachBatch(save_to_db) \
    .option("checkpointLocation", "/tmp/checkpoint") \
    .start()

print("스트리밍 시작!")
query.awaitTermination()  # 5분 실행
# Out:
# 10초 윈도우로 재시작!
# 26/03/19 16:44:17 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 26/03/19 16:44:17 WARN TaskSetManager: Lost task 0.0 in stage 1398.0 (TID 140457) (10.255.255.254 executor driver): TaskKilled (Stage cancelled: Job 699 cancelled part of cancelled job group bbf04686-ccbc-4728-afc5-eb124fbeb90e)
# 26/03/19 16:44:17 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# 배치 0 저장 완료! (0개)
# 배치 1 저장 완료! (5개)
# 배치 2 저장 완료! (5개)
# 배치 3 저장 완료! (6개)
# 배치 4 저장 완료! (5개)
# 배치 5 저장 완료! (5개)
# 배치 6 저장 완료! (5개)
# 배치 7 저장 완료! (9개)
# 배치 8 저장 완료! (5개)
# 배치 9 저장 완료! (4개)
# 배치 10 저장 완료! (5개)
# 배치 11 저장 완료! (5개)
# 배치 12 저장 완료! (9개)
# 배치 13 저장 완료! (5개)
# 배치 14 저장 완료! (5개)
# 배치 15 저장 완료! (5개)
# 배치 16 저장 완료! (5개)
# 배치 17 저장 완료! (8개)
# 배치 18 저장 완료! (5개)
# 배치 19 저장 완료! (5개)
# 배치 20 저장 완료! (5개)
# 배치 21 저장 완료! (9개)
# 배치 22 저장 완료! (5개)
# 배치 23 저장 완료! (5개)
# 배치 24 저장 완료! (5개)
# 배치 25 저장 완료! (5개)
# 배치 26 저장 완료! (8개)
# 배치 27 저장 완료! (5개)
# 배치 28 저장 완료! (5개)
# 배치 29 저장 완료! (5개)
# 배치 30 저장 완료! (5개)
# 배치 31 저장 완료! (6개)
# 배치 32 저장 완료! (5개)
# 배치 33 저장 완료! (5개)
# 배치 34 저장 완료! (5개)
# 배치 35 저장 완료! (5개)
# 배치 36 저장 완료! (6개)
# 배치 37 저장 완료! (5개)
# 배치 38 저장 완료! (5개)
# 배치 39 저장 완료! (5개)
# 배치 40 저장 완료! (5개)
# 배치 41 저장 완료! (6개)
# 배치 42 저장 완료! (5개)
# 배치 43 저장 완료! (5개)
# 배치 44 저장 완료! (5개)
# 배치 45 저장 완료! (5개)
# 배치 46 저장 완료! (8개)
# 배치 47 저장 완료! (5개)
# 배치 48 저장 완료! (5개)
# 배치 49 저장 완료! (5개)
# 배치 50 저장 완료! (5개)
# 배치 51 저장 완료! (5개)
# 배치 52 저장 완료! (6개)
# 배치 53 저장 완료! (5개)
# 배치 54 저장 완료! (5개)
# 배치 55 저장 완료! (5개)
# 배치 56 저장 완료! (5개)
# 배치 57 저장 완료! (6개)
# 배치 58 저장 완료! (5개)
# 배치 59 저장 완료! (5개)
# 배치 60 저장 완료! (5개)
# 배치 61 저장 완료! (7개)
# 배치 62 저장 완료! (5개)
# 배치 63 저장 완료! (5개)
# 배치 64 저장 완료! (5개)
# 배치 65 저장 완료! (5개)
# 배치 66 저장 완료! (9개)
# 배치 67 저장 완료! (5개)
# 배치 68 저장 완료! (5개)
# 배치 69 저장 완료! (5개)
# 배치 70 저장 완료! (5개)
# 배치 71 저장 완료! (9개)
# 배치 72 저장 완료! (5개)
# 배치 73 저장 완료! (5개)
# 배치 74 저장 완료! (5개)
# 배치 75 저장 완료! (5개)
# 배치 76 저장 완료! (10개)
# 배치 77 저장 완료! (5개)
# 배치 78 저장 완료! (5개)
# 배치 79 저장 완료! (5개)
# 배치 80 저장 완료! (4개)
# 배치 81 저장 완료! (10개)
# 배치 82 저장 완료! (5개)
# 배치 83 저장 완료! (5개)
# 배치 84 저장 완료! (5개)
# 배치 85 저장 완료! (5개)
# 배치 86 저장 완료! (9개)
# 배치 87 저장 완료! (5개)
# 배치 88 저장 완료! (5개)
# 배치 89 저장 완료! (5개)
# 배치 90 저장 완료! (5개)
# 배치 91 저장 완료! (5개)
# 배치 92 저장 완료! (5개)
# 배치 93 저장 완료! (5개)
# 배치 94 저장 완료! (5개)
# 배치 95 저장 완료! (5개)
# 배치 96 저장 완료! (5개)
# 배치 97 저장 완료! (6개)
# 배치 98 저장 완료! (5개)
# 배치 99 저장 완료! (5개)
# 배치 100 저장 완료! (5개)
# 배치 101 저장 완료! (5개)
# 배치 102 저장 완료! (7개)
# 배치 103 저장 완료! (5개)
# 배치 104 저장 완료! (5개)
# 배치 105 저장 완료! (5개)
# 배치 106 저장 완료! (10개)
# 배치 107 저장 완료! (5개)
# 배치 108 저장 완료! (5개)
# 배치 109 저장 완료! (5개)
# 배치 110 저장 완료! (5개)
# 배치 111 저장 완료! (5개)
# 배치 112 저장 완료! (5개)
# 배치 113 저장 완료! (5개)
# 배치 114 저장 완료! (6개)
# 배치 115 저장 완료! (5개)
# 배치 116 저장 완료! (5개)
# 배치 117 저장 완료! (5개)
# 배치 118 저장 완료! (9개)
# 배치 119 저장 완료! (5개)
# 배치 120 저장 완료! (5개)
# 배치 121 저장 완료! (5개)
# 배치 122 저장 완료! (5개)
# 배치 123 저장 완료! (8개)
# 배치 124 저장 완료! (5개)
# 배치 125 저장 완료! (5개)
# 배치 126 저장 완료! (5개)
# 배치 127 저장 완료! (10개)
# 배치 128 저장 완료! (5개)
# 배치 129 저장 완료! (5개)
# 배치 130 저장 완료! (10개)
# 배치 131 저장 완료! (5개)
# 배치 132 저장 완료! (5개)
# 배치 133 저장 완료! (5개)
# 배치 134 저장 완료! (8개)
# 배치 135 저장 완료! (5개)
# 배치 136 저장 완료! (5개)
# 배치 137 저장 완료! (5개)
# 배치 138 저장 완료! (5개)
# 배치 139 저장 완료! (5개)
# 배치 140 저장 완료! (5개)
# 배치 141 저장 완료! (5개)
# 배치 142 저장 완료! (5개)
# 배치 143 저장 완료! (5개)
# 배치 144 저장 완료! (6개)
# 배치 145 저장 완료! (5개)
# 배치 146 저장 완료! (5개)
# 배치 147 저장 완료! (5개)
# 배치 148 저장 완료! (9개)
# 배치 149 저장 완료! (5개)
# 배치 150 저장 완료! (5개)
# 배치 151 저장 완료! (5개)
# 배치 152 저장 완료! (5개)
# 배치 153 저장 완료! (6개)
# 배치 154 저장 완료! (5개)
# 배치 155 저장 완료! (5개)
# 배치 156 저장 완료! (5개)
# 배치 157 저장 완료! (10개)
# 배치 158 저장 완료! (5개)
# 배치 159 저장 완료! (5개)
# 배치 160 저장 완료! (5개)
# 배치 161 저장 완료! (5개)
# 배치 162 저장 완료! (9개)
# 배치 163 저장 완료! (5개)
# 배치 164 저장 완료! (5개)
# 배치 165 저장 완료! (5개)
# 배치 166 저장 완료! (5개)
# 배치 167 저장 완료! (10개)
# 배치 168 저장 완료! (5개)
# 배치 169 저장 완료! (5개)
# 배치 170 저장 완료! (5개)
# 배치 171 저장 완료! (8개)
# 배치 172 저장 완료! (5개)
# 배치 173 저장 완료! (5개)
# 배치 174 저장 완료! (5개)
# 배치 175 저장 완료! (9개)
# 배치 176 저장 완료! (5개)
# 배치 177 저장 완료! (5개)
# 배치 178 저장 완료! (5개)
# 배치 179 저장 완료! (10개)
# 배치 180 저장 완료! (5개)
# 배치 181 저장 완료! (5개)
# 배치 182 저장 완료! (5개)
# 배치 183 저장 완료! (5개)
# 배치 184 저장 완료! (6개)
# 배치 185 저장 완료! (5개)
# 배치 186 저장 완료! (5개)
# 배치 187 저장 완료! (5개)
# 배치 188 저장 완료! (5개)
# 배치 189 저장 완료! (6개)
# 배치 190 저장 완료! (5개)
# 배치 191 저장 완료! (5개)
# 배치 192 저장 완료! (5개)
# 배치 193 저장 완료! (10개)
# 배치 194 저장 완료! (5개)
# 배치 195 저장 완료! (5개)
# 배치 196 저장 완료! (5개)
# 배치 197 저장 완료! (10개)
# 배치 198 저장 완료! (5개)
# 배치 199 저장 완료! (5개)
# 배치 200 저장 완료! (5개)
# 배치 201 저장 완료! (7개)
# 배치 202 저장 완료! (5개)
# 배치 203 저장 완료! (5개)
# 배치 204 저장 완료! (5개)
# 배치 205 저장 완료! (5개)
# 배치 206 저장 완료! (5개)
# 배치 207 저장 완료! (5개)
# 배치 208 저장 완료! (5개)
# 배치 209 저장 완료! (5개)
# 배치 210 저장 완료! (10개)
# 배치 211 저장 완료! (5개)
# 배치 212 저장 완료! (5개)
# 배치 213 저장 완료! (5개)
# 배치 214 저장 완료! (5개)
# 배치 215 저장 완료! (9개)
# 배치 216 저장 완료! (5개)
# 배치 217 저장 완료! (5개)
# 배치 218 저장 완료! (5개)
# 배치 219 저장 완료! (5개)
# 배치 220 저장 완료! (6개)
# 배치 221 저장 완료! (5개)
# 배치 222 저장 완료! (5개)
# 배치 223 저장 완료! (5개)
# 배치 224 저장 완료! (10개)
# 배치 225 저장 완료! (5개)
# 배치 226 저장 완료! (5개)
# 배치 227 저장 완료! (5개)
# 배치 228 저장 완료! (6개)
# 배치 229 저장 완료! (5개)
# 배치 230 저장 완료! (5개)
# 배치 231 저장 완료! (5개)
# 배치 232 저장 완료! (10개)
# 배치 233 저장 완료! (5개)
# 배치 234 저장 완료! (5개)
# 배치 235 저장 완료! (5개)
# 배치 236 저장 완료! (5개)
# 배치 237 저장 완료! (8개)
# 배치 238 저장 완료! (5개)
# 배치 239 저장 완료! (5개)
# 배치 240 저장 완료! (5개)
# 배치 241 저장 완료! (5개)
# 배치 242 저장 완료! (9개)
# 배치 243 저장 완료! (5개)
# 배치 244 저장 완료! (5개)
# 배치 245 저장 완료! (5개)
# 배치 246 저장 완료! (5개)
# 배치 247 저장 완료! (9개)
# 배치 248 저장 완료! (5개)
# 배치 249 저장 완료! (5개)
# 배치 250 저장 완료! (5개)
# 배치 251 저장 완료! (5개)
# 배치 252 저장 완료! (7개)
# 배치 253 저장 완료! (5개)
# 배치 254 저장 완료! (5개)
# 배치 255 저장 완료! (5개)
# 배치 256 저장 완료! (10개)
# 배치 257 저장 완료! (5개)
# 배치 258 저장 완료! (5개)
# 배치 259 저장 완료! (5개)
# 배치 260 저장 완료! (9개)
# 배치 261 저장 완료! (5개)
# 배치 262 저장 완료! (5개)
# 배치 263 저장 완료! (6개)
# 배치 264 저장 완료! (5개)
# 배치 265 저장 완료! (5개)
# 배치 266 저장 완료! (5개)
# 배치 267 저장 완료! (10개)
# 배치 268 저장 완료! (5개)
# 배치 269 저장 완료! (5개)
# 배치 270 저장 완료! (5개)
# 배치 271 저장 완료! (5개)
# 배치 272 저장 완료! (9개)
# 배치 273 저장 완료! (5개)
# 배치 274 저장 완료! (5개)
# 배치 275 저장 완료! (5개)
# 배치 276 저장 완료! (5개)
# 배치 277 저장 완료! (7개)
# 배치 278 저장 완료! (5개)
# 배치 279 저장 완료! (5개)
# 배치 280 저장 완료! (5개)
# 배치 281 저장 완료! (9개)
# 배치 282 저장 완료! (5개)
# 배치 283 저장 완료! (5개)
# 배치 284 저장 완료! (5개)
# 배치 285 저장 완료! (5개)
# 배치 286 저장 완료! (9개)
# 배치 287 저장 완료! (5개)
# 배치 288 저장 완료! (5개)
# 배치 289 저장 완료! (5개)
# 배치 290 저장 완료! (5개)
# 배치 291 저장 완료! (5개)
# 배치 292 저장 완료! (5개)
# 배치 293 저장 완료! (5개)
# 배치 294 저장 완료! (5개)
# 배치 295 저장 완료! (5개)
# 배치 296 저장 완료! (5개)
# 배치 297 저장 완료! (5개)
# 배치 298 저장 완료! (5개)
# 배치 299 저장 완료! (6개)
# 배치 300 저장 완료! (5개)
# 배치 301 저장 완료! (5개)
# 배치 302 저장 완료! (5개)
# 배치 303 저장 완료! (9개)
# 배치 304 저장 완료! (5개)
# 배치 305 저장 완료! (5개)
# 배치 306 저장 완료! (5개)
# 배치 307 저장 완료! (5개)
# 배치 308 저장 완료! (10개)
# 배치 309 저장 완료! (5개)
# 배치 310 저장 완료! (5개)
# 배치 311 저장 완료! (5개)
# 배치 312 저장 완료! (5개)
# 배치 313 저장 완료! (10개)
# 배치 314 저장 완료! (5개)
# 배치 315 저장 완료! (5개)
# 배치 316 저장 완료! (5개)
# 배치 317 저장 완료! (5개)
# 배치 318 저장 완료! (6개)
# 배치 319 저장 완료! (5개)
# 배치 320 저장 완료! (5개)
# 배치 321 저장 완료! (5개)
# 배치 322 저장 완료! (10개)
# 배치 323 저장 완료! (5개)
# 배치 324 저장 완료! (5개)
# 배치 325 저장 완료! (5개)
# 배치 326 저장 완료! (9개)
# 배치 327 저장 완료! (5개)
# 배치 328 저장 완료! (5개)
# 배치 329 저장 완료! (5개)
# 배치 330 저장 완료! (5개)
# 배치 331 저장 완료! (6개)
# 배치 332 저장 완료! (5개)
# 배치 333 저장 완료! (5개)
# 배치 334 저장 완료! (5개)
# 배치 335 저장 완료! (9개)
# 배치 336 저장 완료! (5개)
# 배치 337 저장 완료! (5개)
# 배치 338 저장 완료! (5개)
# 배치 339 저장 완료! (5개)
# 배치 340 저장 완료! (6개)
# 배치 341 저장 완료! (5개)
# 배치 342 저장 완료! (5개)
# 배치 343 저장 완료! (5개)
# 배치 344 저장 완료! (5개)
# 배치 345 저장 완료! (5개)
# 배치 346 저장 완료! (5개)
# 배치 347 저장 완료! (5개)
# 배치 348 저장 완료! (5개)
# 배치 349 저장 완료! (9개)
# 배치 350 저장 완료! (5개)
# 배치 351 저장 완료! (5개)
# 배치 352 저장 완료! (5개)
# 배치 353 저장 완료! (8개)
# 배치 354 저장 완료! (5개)
# 배치 355 저장 완료! (5개)
# 배치 356 저장 완료! (5개)
# 배치 357 저장 완료! (10개)
# 배치 358 저장 완료! (5개)
# 배치 359 저장 완료! (5개)
# 배치 360 저장 완료! (5개)
# 배치 361 저장 완료! (9개)
# 배치 362 저장 완료! (5개)
# 배치 363 저장 완료! (5개)
# 배치 364 저장 완료! (5개)
# 배치 365 저장 완료! (5개)
# 배치 366 저장 완료! (6개)
# 배치 367 저장 완료! (5개)
# 배치 368 저장 완료! (5개)
# 배치 369 저장 완료! (5개)
# 배치 370 저장 완료! (5개)
# 배치 371 저장 완료! (5개)
# 배치 372 저장 완료! (5개)
# 배치 373 저장 완료! (5개)
# 배치 374 저장 완료! (5개)
# 배치 375 저장 완료! (9개)
# 배치 376 저장 완료! (5개)
# 배치 377 저장 완료! (5개)
# 배치 378 저장 완료! (5개)
# 배치 379 저장 완료! (10개)
# [Stage 2161:=================================>                 (131 + 12) / 200]
